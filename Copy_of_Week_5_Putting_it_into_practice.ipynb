# %% [markdown]
# <a href="https://colab.research.google.com/github/tomormerod/GEOG3003M/blob/main/Copy_of_Week_5_Putting_it_into_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GEOG5003M Week 5: Putting it into Practice
#
# This week we are going to put into practice your data science skills developed over the last 4 weeks (Reading in data, exploring data, data summarisation, data cleaning and data visualisation).
#
# ## The Data
# We are going to be using some data this week about output areas in England and Wales. I have joined together some data for you form the census. Some of the data is typical census data ('Population, Males, Females, Economic Activity) and some are data derived from the census (the Consumer Vulnerability Index and the Output Area Classification (see Lecture slides and Data Info at the end of the notebook for more information)).
#
#
# ### Data Summary Table

# %% [markdown]
# | Variable | Description | mean | std | min | 25% | 50% | 75% | max | Link to source|
# |---|---|---|---|---|---|---|---|---|---|
# | All usual residents | Number of usual residents in the OA | 309.1149 | 82.97214 | 91 | 264 | 303 | 344 | 4140 | https://www.nomisweb.co.uk |
# | Males | Number of Males in the OA | 151.9965 | 45.63066 | 20 | 128 | 148 | 170 | 1994 | https://www.nomisweb.co.uk |
# | Females | Number of Females in the OA | 157.1184 | 41.96267 | 12 | 135 | 155 | 176 | 2146 | https://www.nomisweb.co.uk |
# | output_area | Output area code | NaN | NaN | NaN | NaN | NaN | NaN | NaN | https://data.cdrc.ac.uk/dataset/consumer-vulnerability |
# | Consumer_Vulnerability | Consumer vulnerability pen portrait | NaN | NaN | NaN | NaN | NaN | NaN | NaN | https://data.cdrc.ac.uk/dataset/consumer-vulnerability |
# | consumer_vulnerability_cluster | Consumer vulnerability cluster | NaN | NaN | NaN | NaN | NaN | NaN | NaN | https://data.cdrc.ac.uk/dataset/consumer-vulnerability |
# | OA_SA | Output area code | NaN | NaN | NaN | NaN | NaN | NaN | NaN | https://data.cdrc.ac.uk/dataset/output-area-classification-2011 |
# | SUB_REGION | Sub region of the UK | NaN | NaN | NaN | NaN | NaN | NaN | NaN | https://data.cdrc.ac.uk/dataset/output-area-classification-2011 |
# | REGION | Region of the UK | NaN | NaN | NaN | NaN | NaN | NaN | NaN | https://data.cdrc.ac.uk/dataset/output-area-classification-2011 |
# | POPULATION | Population of OA | 309.1149 | 82.97214 | 91 | 264 | 303 | 344 | 4140 | https://data.cdrc.ac.uk/dataset/output-area-classification-2011 |
# | OAC_super_group_code | Output Area Classification Super Group Code | NaN | NaN | NaN | NaN | NaN | NaN | NaN | https://data.cdrc.ac.uk/dataset/output-area-classification-2011 |
# | OAC_group_code | Output Area Classification Group Code | NaN | NaN | NaN | NaN | NaN | NaN | NaN | https://data.cdrc.ac.uk/dataset/output-area-classification-2011 |
# | OAC_subgroup_code | Output Area Classification Sub-Group Code | NaN | NaN | NaN | NaN | NaN | NaN | NaN | https://data.cdrc.ac.uk/dataset/output-area-classification-2011 |
# | OAC_super_group_name | Output Area Classification Super Group Name | NaN | NaN | NaN | NaN | NaN | NaN | NaN | https://data.cdrc.ac.uk/output-area-classification-2011/resource/pen-portraits-2011-output-area-classification/resource/pen-portraits-2011-output-area-classification |
# | OAC_group_name | Output Area Classification Group Name | NaN | NaN | NaN | NaN | NaN | NaN | NaN | https://data.cdrc.ac.uk/output-area-classification-2011/resource/pen-portraits-2011-output-area-classification/resource/pen-portraits-2011-output-area-classification |
# | OAC_subgroup_name | Output Area Classification Sub-Group Name | NaN | NaN | NaN | NaN | NaN | NaN | NaN | https://data.cdrc.ac.uk/output-area-classification-2011/resource/pen-portraits-2011-output-area-classification/resource/pen-portraits-2011-output-area-classification |
# | Economically_active_perecentage | % of population economically active | 69.56294 | 9.364096 | 4.9 | 64.2 | 70.3 | 75.7 | 99.1 | https://www.nomisweb.co.uk |
# | Economically_active_In_employment_perecentage | % of economically active population in active employment  | 62.00594 | 11.0586 | 0.6 | 56 | 63.4 | 69.4 | 98.2 | https://www.nomisweb.co.uk |
# | Economically_active_Unemployed_perecentage | % of economically active unemployment | 4.422425 | 3.085969 | 0 | 2.2 | 3.6 | 5.9 | 46.9 | https://www.nomisweb.co.uk |
# | Economically_active_Full-time_student_perecentage | % of economically active population that are full time students | 3.134178 | 2.715611 | 0 | 1.7 | 2.7 | 3.8 | 55.5 | https://www.nomisweb.co.uk |
# | Economically_Inactive_perecentage | % of population that are economically inactive | 30.43704 | 9.364099 | 0.9 | 24.3 | 29.7 | 35.8 | 95.1 | https://www.nomisweb.co.uk |
# | Economically_inactive_Retired_perecentage | % of population that are economically inactive and retired | 14.54672 | 8.154455 | 0 | 8.7 | 13.4 | 19 | 93.8 | https://www.nomisweb.co.uk |
# | Economically_inactive_Student_including_full-time_students_perecentage | % of population that are economically inactive and students | 5.119019 | 5.590758 | 0 | 2.7 | 4 | 5.8 | 88.4 | https://www.nomisweb.co.uk |
# | Economically_inactive_Looking_after_home_or_family_perecentage | % of population that are economically inactive and are looking after family/home | 4.318384 | 2.658258 | 0 | 2.5 | 3.8 | 5.5 | 39.4 | https://www.nomisweb.co.uk |
# | Economically_inactive_Long-term_sick_or_disabled_perecentage | % of population that are economically inactive and are sick or disabled  | 4.340841 | 3.828691 | 0 | 1.6 | 3.2 | 6 | 46.1 | https://www.nomisweb.co.uk |
# | Economically_inactive_Other_perecentage | % of population that are economically inactive that are not retired, students, looking after the home, sick or disabled | 2.111315 | 2.14308 | 0 | 0.9 | 1.7 | 2.8 | 75.2 | https://www.nomisweb.co.uk |
# | 2011_output_area | Output area code | NaN | NaN | NaN | NaN | NaN | NaN | NaN | https://www.nomisweb.co.uk |

# %% [markdown]
# ### Uploading files in Google Collab:
# 1) Select files on the left hand side (folder icon)
# 2) Select 'Upload to session storage'
# 3) Upload the OA_GEOG990M_data.csv.zip file from Minerva
#
# <img src="https://github.com/FrancescaPontin/GEOG5003M/blob/main/screenshots/week_18_screenshot_1.png?raw=1" alt="drawing" width="800"/>
# <img src="https://github.com/FrancescaPontin/GEOG5003M/blob/main/screenshots/week_18_screenshot_2.png?raw=1" alt="drawing" width="300"/>

# %% [markdown]
# ## Week 18 Challenge:
#
# Using the skills you have developed over the last 4 weeks can you answer the following questions. Don't forget the 'data science approach' we dicsussed in the first week.
#
# ### Data Summary
#
# - #### What are the data types in the provided data?
#     - Are the data types as expected?
# **All of the classifications are objects (strings) except OAC Supergroup Code.**
#     - Do we need to change any data types?
# **OAC Supergroup Code -> object.**
#
# ### Data Cleaning
# - Is there any missing data?
# **The number of non-null data points appears to be identical**
# - Can you create any further summary variables derived from the exisiting data?
#     - E.g. % Female, % Male. These need to be of the float64 type.
#     **Some of the economically in/active variables can be combined**
# - Do you want to make the variable naming conventions uniform e.g. all lowercase. Ja. Use the .str.lower function. Also need to use underscores.
# - Are there any outliers
#     -  Can you use a visualisation to explore this? **Pairwise function to plot the full range of all the variables against each other**
#     -  Are any outliers expected or is there any issue with the data? **There are several duplicates that need to be dropped**
#
# ### Data Exploration
# - #### What does the data look like
#     - How many regions are there? **10**
#     - What is the most common OAC super group? **suburbanites - Group 6**
#     - Which OA group is least common? **Constrained flat dwellers - 7b**
#     - Which consumer vulnerability cluster is most common? **Well Established**
#     - What is the average % of the population that is economicallty active? **69.6%**
#
# - #### How do the variables relate to one another?
#     - Which 'sub-regions' are within each region? **8802 (NE) - 27638 (SE)**
#     - How many OAs are there in each sub-region? **9 (Ilses of Scilly) - 3223 (Birmingham)**
#     -  <i>Hint: Look back at the <code>.groupby()</code> function </i>
#     - What does a <code> sns.pairplot()</code> tell you about the relationship between the numeric data? Can you add <code>hue=</code> to include further info about the categorical variables? **The best correlations are between EA in employment and economically inactive, active full time student and inactive student (all), active unemployed and inactive disabled.**
#
# -  #### Can you subset the data to look at the 'SUB_REGION' of 'Leeds'?
#     - <i>Hint: Look back at the <code>.loc[]</code> function </i>
#
# ### Data Visualisation
# <font color  ='red'> Don't forget to refer back to the Grammar of Graphics and the lecture slides to ensure we are making beautiful and accessible visualiations?
# - Can you visualise the relationship between the 'POPULATION' variable and the 'OAC_super_group_code' variable? **Done**
# - Can you visualise the relationship between the 'POPULATION' variable and the  'Consumer_Vulnerability' variable? **Done**
# - Can you create a violin plot showing the 'Economically_active_In_employment_perecentage' by 'consumer_vulnerability_cluster'? **Done**
# - Can you create a swarm plot showing the 'Economically_Inactive_perecentage' by 'consumer_vulnerability_cluster'? **Done**

# %%
## import required packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# The data was up[loaded as a zip file,
#  pandas can read in compressed file, we just need to tell it how the file has been comprressed (to a zip file)

# collab users remove '../data/week_18/' filepath
output_areas = pd.read_csv('OA_GEOG990M_data.csv.zip',compression='zip', )

# %%
# Look at the colums in the data
output_areas.columns
# Out:
# Index(['Unnamed: 0', 'Area', 'All usual residents', 'Males', 'Females',
#        'output_area', 'Consumer_Vulnerability',
#        'consumer_vulnerability_cluster', 'OA_SA', 'SUB_REGION', 'REGION',
#        'POPULATION', 'OAC_super_group_code', 'OAC_group_code',
#        'OAC_subgroup_code', 'OAC_super_group_name', 'OAC_group_name',
#        'OAC_subgroup_name', '_merge', 'Economically_active_perecentage',
#        'Economically_active_In_employment_perecentage',
#        'Economically_active_Unemployed_perecentage',
#        'Economically_active_Full-time_student_perecentage',
#        'Economically_Inactive_perecentage',
#        'Economically_inactive_Retired_perecentage',
#        'Economically_inactive_Student_including_full-time_students_perecentage',
#        'Economically_inactive_Looking_after_home_or_family_perecentage',
#        'Economically_inactive_Long-term_sick_or_disabled_perecentage',
#        'Economically_inactive_Other_perecentage', '2011_output_area'],
# ...

# %%
output_areas.describe()
# Out:
#           Unnamed: 0  All usual residents          Males        Females  \
# count  181408.000000        181408.000000  181408.000000  181408.000000
# mean    90703.500000           309.114879     151.996472     157.118407
# std     52368.123154            82.972143      45.630659      41.962670
# min         0.000000            91.000000      20.000000      12.000000
# 25%     45351.750000           264.000000     128.000000     135.000000
# 50%     90703.500000           303.000000     148.000000     155.000000
# 75%    136055.250000           344.000000     170.000000     176.000000
# max    181407.000000          4140.000000    1994.000000    2146.000000
#
#           POPULATION  OAC_super_group_code  Economically_active_perecentage  \
# count  181408.000000         181408.000000                    181408.000000
# mean      309.114879              5.053625                        69.562937
# std        82.972143              2.187411                         9.364096
# ...

# %%
output_areas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181408 entries, 0 to 181407
# Data columns (total 30 columns):
#  #   Column                                                                  Non-Null Count   Dtype
# ---  ------                                                                  --------------   -----
#  0   Unnamed: 0                                                              181408 non-null  int64
#  1   Area                                                                    181408 non-null  object
#  2   All usual residents                                                     181408 non-null  int64
#  3   Males                                                                   181408 non-null  int64
#  4   Females                                                                 181408 non-null  int64
#  5   output_area                                                             181408 non-null  object
# ...

# %%
output_areas.columns = output_areas.columns.str.lower()
output_areas.rename(columns={'all usual residents':'total_residents', 'unnamed: 0':'index'}, inplace=True)

# %%
output_areas.columns
# Out:
# Index(['index', 'area', 'total_residents', 'males', 'females', 'output_area',
#        'consumer_vulnerability', 'consumer_vulnerability_cluster', 'oa_sa',
#        'sub_region', 'region', 'population', 'oac_super_group_code',
#        'oac_group_code', 'oac_subgroup_code', 'oac_super_group_name',
#        'oac_group_name', 'oac_subgroup_name',
#        'economically_active_perecentage',
#        'economically_active_in_employment_perecentage',
#        'economically_active_unemployed_perecentage',
#        'economically_active_full-time_student_perecentage',
#        'economically_inactive_perecentage',
#        'economically_inactive_retired_perecentage',
#        'economically_inactive_student_including_full-time_students_perecentage',
#        'economically_inactive_looking_after_home_or_family_perecentage',
#        'economically_inactive_long-term_sick_or_disabled_perecentage',
#        'economically_inactive_other_perecentage'],
#       dtype='object')

# %%
output_areas = output_areas.drop(['total_residents'],axis=1)

# %%
output_areas['population']=output_areas['population'].astype('int64')
output_areas['oac_super_group_code']=output_areas['oac_super_group_code'].astype('object')
output_areas.dtypes
# Out:
# males                                                                       int64
# females                                                                     int64
# consumer_vulnerability                                                     object
# consumer_vulnerability_cluster                                             object
# oa_sa                                                                      object
# sub_region                                                                 object
# region                                                                     object
# population                                                                  int64
# oac_super_group_code                                                       object
# oac_group_code                                                             object
# oac_subgroup_code                                                          object
# ...

# %%
output_areas['male_percentage']=output_areas['males']/output_areas['population']
output_areas['female_percentage']=output_areas['females']/output_areas['population']

# %%
output_areas.rename(columns={'consumer_vulnerability_cluster': 'cluster_code', 'consumer_vulnerability':'cluster_name'}, inplace=True)

# %%
sns.catplot(x='cluster_code', y = 'economically_inactive_perecentage' , height = 10, kind = 'violin', hue = 'cluster_name', data=output_areas);

# %%
output_areas['REGION'].mode()
# Out:
# 0    South East
# Name: REGION, dtype: object

# %%
oa_numbers = output_areas.select_dtypes(include='float64', exclude='int64')
sns.pairplot(oa_numbers);

# %%
oa_numbers.corr()
# set figure size
plt.figure(figsize=(8,8))
# plot a heatmap of the correlation table created above, annot= True annotates the cells with the correlation value
sns.heatmap(oa_numbers.corr(), annot=True, cmap='viridis');

# %%
output_areas.loc[output_areas['sub_region']=='Leeds']
# Out:
#         males  females                      cluster_name cluster_code  \
# 55046     134      145                       On a Budget            D
# 55047     145      151          Prosperous Professionals            A
# 55048     186      221          Prosperous Professionals            A
# 55049     114      132             Vulnerable Pensioners            F
# 55050     137      135          Prosperous Professionals            A
# ...       ...      ...                               ...          ...
# 165761     71       79          Prosperous Professionals            A
# 166025    129      130          Prosperous Professionals            A
# 166026    142      128          Prosperous Professionals            A
# 166027    186      208                  Well Established            B
# 166028    103      110  Students and Young Professionals            C
#
#             oa_sa sub_region                    region  population  \
# ...

# %%
from matplotlib.colors import Normalize

#Colormap X
cmap_x = plt.colormaps['Greens']
# Normalize x values.
norm_x = Normalize(vmin=min(output_areas['Economically_active_In_employment_perecentage']), vmax=max(output_areas['Economically_active_In_employment_perecentage']))
# Map the normalized values to colors.
color_values_x = cmap_x(norm_x(output_areas['Economically_active_In_employment_perecentage']))

#Colormap Y
cmap_y = plt.colormaps['Reds']
# Normalize y values.
norm_y = Normalize(vmin=min(output_areas['Economically_Inactive_perecentage']), vmax=max(output_areas['Economically_Inactive_perecentage']))
# Map the normalized values to colors.
color_values_y = cmap_y(norm_y(output_areas['Economically_Inactive_perecentage']))

g = sns.JointGrid(height = 7)
sns.scatterplot(data=output_areas, x='Economically_active_In_employment_perecentage', y='Economically_Inactive_perecentage', hue='Consumer_Vulnerability', palette="Blues", ax=g.ax_joint, s=30, marker='.', legend='brief')
g.fig.suptitle('Economically active (employed) %, Economically inactive % Bivariate and Univariate Plots')
g.fig.subplots_adjust(top=0.9)

fig = plt.figure()
plt.xticks([])
plt.yticks([])
fig.set_size_inches(0,0)
ax = plt.axes()
n, bins, patches_x = g.ax_marg_x.hist(x=output_areas['Economically_active_In_employment_perecentage'], bins=25)

ax = plt.axes()
n, bins, patches_y = g.ax_marg_y.hist(x=output_areas['Economically_Inactive_perecentage'], bins=25, orientation= 'horizontal')

# Get the bin centers
bin_centers = [(bins[i] + bins[i+1]) / 2 for i in range(len(bins) - 1)]

# Apply the colormap to the patches
for i, patch in enumerate(patches_x):
    # Use bin centers for color
    patch.set_facecolor(cmap_x(norm_x(bin_centers[i])))

#And for Y
for i, patch in enumerate(patches_y):
    # Use bin centers for color
    patch.set_facecolor(cmap_y(norm_y(bin_centers[i])))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# ...

# %%
from matplotlib.colors import Normalize
#from matplotlib.cm import
#import matplotlib.pyplot as plt
#import seaborn as sns

#Colormap X
cmap_x = plt.colormaps['Reds']
# Normalize x values.
norm_x = Normalize(vmin=min(output_areas['Economically_active_In_employment_perecentage']), vmax=max(output_areas['Economically_active_In_employment_perecentage']))
# Map the normalized values to colors.
color_values_x = cmap_x(norm_x(output_areas['Economically_active_In_employment_perecentage']))

# Create the histogram
fig = plt.subplot()
ax = plt.axes()
n, bins, patches = ax.hist(x=output_areas['Economically_active_In_employment_perecentage'], bins=25)

# Get the bin centers
bin_centers = [(bins[i] + bins[i+1]) / 2 for i in range(len(bins) - 1)]

# Apply the colormap to the patches
for i, patch in enumerate(patches):
    patch.set_facecolor(cmap_x(norm_x(bin_centers[i])))  # Use bin centers for color

# Show the plot
plt.show()

# %% [markdown]
# # Data Info
# -----------
# ## Consumer Vulnerability
#
# Read about the data here: https://data.cdrc.ac.uk/dataset/consumer-vulnerability
#
# ### Project Background
#
# Some consumers are more vulnerable to marketing practices due to their personal traits such age, health or household makeup. This vulnerability varies by product and industry. Consumer vulnerability here is defined as the risk that a consumer’s mental, physical or financial welfare may be damaged when engaging in a market interaction.
#
# While consumer vulnerability has been discussed at length in academic literature and regulatory guidelines, there has not been a comprehensive geographical assessment of consumer vulnerability in the United Kingdom. This study creates a geodemographic classification of consumer vulnerability at output area level.
#
# ### Data and Methods
#
# The variables selected to use for clustering were derived from 2011 Census outputs, based on the whether they suitably describe consumer vulnerability as defined above. In addition data from a commercial partner was used for cluster validation.
#
# Highly correlated variables were considered for removal from the initial selection. Counts were converted to percentages for each output area. Data were then transformed using Inverse Hyperbolic Sine and standardised using z-scores. Principal component analysis was performed on the treated data before clustering.
#
# K-means was performed to cluster the data using the first 10 principal components as inputs. The optimum number of clusters was first determined by running k-means at each value of k (number of clusters) from 2 to 25. This was then used when creating the final clustering.
#
# ### Key Findings
#
# An optimum number of 6 clusters was found using k-means. These clusters were visualised using heat maps and radial plots by comparing clusters to the z-scores of the original variables. Each of these clusters showed distinct characteristics related to consumer vulnerability.
#
# The clusters were characterised as “Prosperous Professionals”, “Well Established”, “Students and Young Professionals”, “On a Budget”, “Vulnerable Communities”, and “Vulnerable Pensioners”.
#
# These cluster results were presented on an interactive map for the United Kingdom, showing cluster membership of each output area (Fig 1). Pen portraits were also written to help end users understand the characteristics of each cluster.
# A consumer dataset was used to validate the clusters, finding a good level of agreement. This involved comparing the cluster solution to key variables such as income, shop spend and holiday spend. In addition to validation this process also generated extra insight into the cluster characteristics, such as spending habits.
#
# Additionally, each cluster was broken down into sub-clusters and characterised using the same methods as above. This produced further insight into the makeup of each of the clusters, further identifying areas with particular vulnerability to market practices.
#
#
# ### Pen Portraits
#
# #### Prosperous Professionals
#
# This group contains a high proportion of people in professional and technical occupations including senior positions. Home ownership in this group high, as is detached housing. There are a large number of married and cohabiting people in this cluster, in particular with children. Full time employment, very good health and 2 or more cars per household are all characteristic of this group. The proportion of people in the age range of 30-44 is high of this group.
#
# The level of vulnerability for this group is considered very low as there are very few characteristics associated with vulnerability.
#
#
#
# #### Well Established
#
# This group contains larger proportion of demographics age 45 and older including a large proportion of retirees and people in professional occupations. A large proportion of the non-retired workers are self-employed. The proportion of home ownership is high, as is people living in detached housing. The proportion of married and cohabiting people is high in this group. The proportion of one person households above 65 is also relatively high, as are people who provide unpaid care. People in this group typically have higher level qualifications. Households typically contain 2 or more cars.
#
# The level of vulnerability for this group is considered low as overall there are few characteristics associated with vulnerability. However, the proportion of households containing a lone person over 60 and people providing unpaid care does increase vulnerability somewhat.
#
#
#
# #### Students and Young Professionals
#
# This group contains a high proportion of full time students and full time employees of around ages 20 to 29. For housing the proportion of flats is high as is private rent. High levels of qualifications and professional occupations are characteristic of this group. Very good health is characteristic of this group. There reasonably high proportion of people with poor English skills in this cluster and households with no cars.
#
# This group does not exhibit many vulnerable characteristics except for poor English speakers and a lack of cars in the household.
#
#
#
# #### On a Budget
#
# This group contains a high proportion of people in trades, sales, and leisure, as well as a high proportion of unemployed or long term sick/disabled. Qualification levels are generally low. The proportion of people with fair or poor health is high, as well as those with limited day to day activities. This group contains high proportions of married/cohabiting people with children and also lone parents. Semi-detached and terraced housing is characteristic of this cluster.
#
# There are several indicators of vulnerability in this cluster meaning that consumer vulnerability is considered fair for this group.
#
#
#
# #### Vulnerable Communities
#
# This group contains a high proportion of people with poor English skills, lone parents, and long term sick/disabled. Flats or terraced housing, and social renting is characteristic of this group. The health of people in this group varies. Unemployment is high and those that are in work are typically in lower paying jobs. A large proportion of homes do not have a car. The age range is young to mid-aged at around 15 to 44.
#
# This group exhibits several vulnerable characteristics suggesting a high level of vulnerability can be found in this group.
#
#
#
# #### Vulnerable Pensioners
#
# The age range for this group is around 60 to 90 with a high proportion of one person households over 65. Social rented flats are characteristic of this cluster, as is having no cars in the household. There are a high proportion of people with limited day-to-day activities, as well as fair to very bad health. The proportion of people with good health is low and with very good health is very low. People in this group who are retired or long-term sick/disabled are characteristic of this group. Those that work are typically in elementary occupations or process, plant and machine operatives.
#
# The level of vulnerability this group is very high as many vulnerable characteristics are present.
#
#
# -----------
#
# ## Output Area Classificaiton
#
# ### Overview
#
# The 2011 Classification for Output Areas (2011 OAC) is a hierarchical geodemographic classification across the UK which identifies areas of the country with similar characteristics. The OAC is produced as a collaboration between the Office for National Statistics and University College London. The classification contains the following breakdown of Output Areas into different groups and sub-groups.
#
#
# #### Supergroups
# There are eight supergroups forming the top tier of the hierarchy, denoted by a number (n) before
# their name in the descriptions below. These provide the most generic descriptions of the population
# in the UK. Descriptions for supergroups that discuss the average are referring to the ‘average’
# characteristics for the UK. If not explicitly stated, comparisons (for example higher or lower) are
# made with the UK as a whole.
# #### Groups
# The middle tier is the group level, of which there are 26, each denoted by a number and letter (nx)
# in the descriptions. These provide a further description of an area’s characteristics, in addition to,
# and comparison with the parent supergroup characteristics. As the 2011 OAC is a top-down
# classification, any group that starts with the same n as a supergroup will have been derived from
# that supergroup only. The supergroups produce two to four groups each. Descriptions for groups
# that refer to the average are referring to the ‘average’ of the parent supergroup, and not the
# national average. If not explicitly stated, comparisons (for example higher or lower) are made with
# the parent supergroup.
# #### Subgroups
# The bottom tier of the 2011 OAC hierarchy is the subgroups. There are 76 of these groups each
# denoted by a number, letter and number (nxn). These descriptions supplement both the parent
# supergroup and parent group characteristics, and comparisons are made with the parent group.
# Any subgroup starting with the same nx as a group means it will have been derived from that group
# only. The groups produce two to four subgroups each. Descriptions for subgroups that refer to the
# average are referring to the average of the parent group, and not the supergroup or national
# ‘average’. If not explicitly stated, comparisons (for example higher or lower) are made with the
# parent group.
#
# | **Super Group** | **Group** | **Sub-group** |
# |:---:|:---:|:---:|
# | Rural Residents | Farming Communities | Rural Workers and Families |
# |  |  | Established Farming Communities |
# |  |  | Agricultural Communities |
# |  |  | Older Farming Communities |
# |  | Rural Tenants | Rural Life |
# |  |  | Rural White-Collar Workers |
# |  |  | Ageing Rural Flat Tenants |
# |  | Ageing Rural Dwellers | Rural Employment and Retirees |
# |  |  | Renting Rural Retirement |
# |  |  | Detached Rural Retirement |
# | Cosmopolitans | Students Around Campus | Student Communal Living |
# |  |  | Student Digs |
# |  |  | Students and Professionals |
# |  | Inner-City Students | Students and Commuters |
# |  |  | Multicultural Student Neighbourhoods |
# |  | Comfortable Cosmopolitans | Migrant Families |
# |  |  | Migrant Commuters |
# |  |  | Professional Service Cosmopolitans |
# |  | Aspiring and Affluent | Urban Cultural Mix |
# |  |  | Highly-Qualified Quaternary Workers |
# |  |  | EU White-Collar Workers |
# | Ethnicity Central | Ethnic Family Life | Established Renting Families |
# |  |  | Young Families and Students |
# |  | Endeavouring Ethnic Mix | Striving Service Workers |
# |  |  | Bangladeshi Mixed Employment |
# |  |  | Multi-Ethnic Professional Service Workers |
# |  | Ethnic Dynamics | Constrained Neighbourhoods |
# |  |  | Constrained Commuters |
# |  | Aspirational Techies | New EU Tech Workers |
# |  |  | Established Tech Workers |
# |  |  | Old EU Tech Workers |
# | Multicultural Metropolitans | Rented Family Living | Social Renting Young Families |
# |  |  | Private Renting New Arrivals |
# |  |  | Commuters with Young Families |
# |  | Challenged Asian Terraces | Asian Terraces and Flats |
# |  |  | Pakistani Communities |
# |  | Asian Traits | Achieving Minorities |
# |  |  | Multicultural New Arrivals |
# |  |  | Inner City Ethnic Mix |
# | Urbanites | Urban Professionals and Families | White Professionals |
# |  |  | Multi-Ethnic Professionals with Families |
# |  |  | Families in Terraces and Flats  |
# |  | Ageing Urban Living | Delayed Retirement |
# |  |  | Communal Retirement |
# |  |  | Self-Sufficient Retirement |
# | Suburbanites | Suburban Achievers | Indian Tech Achievers |
# |  |  | Comfortable Suburbia |
# |  |  | Detached Retirement Living |
# |  |  | Ageing in Suburbia |
# |  | Semi-Detached Suburbia | Multi-Ethnic Suburbia |
# |  |  | White Suburban Communities |
# |  |  | Semi-Detached Ageing |
# |  |  | Older Workers and Retirement |
# | Constrained City Dwellers | Challenged Diversity | Transitional Eastern European Neighbourhoods |
# |  |  | Hampered Aspiration |
# |  |  | Multi-Ethnic Hardship |
# |  | Constrained Flat Dwellers | Eastern European Communities |
# |  |  | Deprived Neighbourhoods |
# |  |  | Endeavouring Flat Dwellers |
# |  | White Communities | Challenged Transitionaries |
# |  |  | Constrained Young Families |
# |  |  | Outer City Hardship |
# |  | Ageing City Dwellers | Ageing Communities and Families |
# |  |  | Retired Independent City Dwellers |
# |  |  | Retired Communal City Dwellers |
# |  |  | Retired City Hardship |
# | Hard-Pressed Living | Industrious Communities | Industrious Transitions |
# |  |  | Industrious Hardship |
# |  | Challenged Terraced Workers | Deprived Blue-Collar Terraces |
# |  |  | Hard-Pressed Rented Terraces |
# |  | Hard-Pressed Ageing Workers | Ageing Industrious Workers |
# |  |  | Ageing Rural Industry Workers |
# |  |  | Renting Hard-Pressed Workers |
# |  | Migration and Churn | Young Hard-Pressed Families |
# |  |  | Hard-Pressed Ethnic Mix |
# |  |  | Hard-Pressed European Settlers |
